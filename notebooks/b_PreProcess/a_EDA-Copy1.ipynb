# %% [markdown]
# **imports**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Loading...**

# %%
df = pd.read_csv("D:\\forecast\\forecast\\data\\sales_BYA.csv", encoding="unicode_escape")

# %%
df.head()
# Out:
#      CID  item_type_id                item_type             size      date  \
# 0  10001           186  BYA LF - Skin Coated FR  1x 1.0 re (1-w)  01-08-22
# 1  10001           186  BYA LF - Skin Coated FR  1x 1.0 re (1-w)  01-08-22
# 2  10001           186  BYA LF - Skin Coated FR  1x 1.0 re (1-w)  01-08-22
# 3  10001           186  BYA LF - Skin Coated FR  1x 1.0 re (1-w)  01-08-22
# 4  10001           186  BYA LF - Skin Coated FR  1x 1.0 re (1-w)  01-08-22
#
#    Category   grade  outlet_id    qtym  Net Price  ...  noc  tlcolt  ecoInd  \
# 0  Domestic  Grade1       1001   500.0    7534.96  ...    5     300    High
# 1  Domestic  Grade1       1003  2000.0   32043.00  ...    4     350    High
# 2  Domestic  Grade1       1004  3000.0   49132.60  ...    7     425    High
# 3  Domestic  Grade1       1005   200.0    2913.00  ...    3     300    High
# 4  Domestic  Grade1       1010   600.0    9476.96  ...    7     150  Medium
#
#    Area (km)^2    dfc  population  literacy_rate   pcx  \
# 0       3085.0  106.0     6785254          0.460  53.3
# 1        928.0  160.0     1823580          0.643  59.6
# 2       5283.0  253.0     9352719          0.460  58.9
# 3       1800.0   26.0     4262296          1.047  56.4
# 4       2492.0  398.5     3078190          0.782  28.3
#
#                         uses  appliation group
# 0  Fan & Lighting Connection           General
# 1  Fan & Lighting Connection           General
# 2  Fan & Lighting Connection           General
# 3  Fan & Lighting Connection           General
# 4  Fan & Lighting Connection           General
#
# [5 rows x 25 columns]

# %%
df.tail()
# Out:
#         CID  item_type_id   item_type              size      date  Category  \
# 5225  10147           180  BYA - FRLS  1 x 2.5 rm (7-w)  08-08-22  Domestic
# 5226  10147           180  BYA - FRLS  1 x 2.5 rm (7-w)  17-08-22  Domestic
# 5227  10149           180  BYA - FRLS        1 x 4.0 rm  02-08-22  Domestic
# 5228  10149           180  BYA - FRLS        1 x 4.0 rm  21-08-22  Domestic
# 5229  10149           180  BYA - FRLS        1 x 4.0 rm  22-08-22  Domestic
#
#        grade  outlet_id    qtym  Net Price  ...  noc  tlcolt  ecoInd  \
# 5225  Grade1       1015  1200.0    50662.8  ...    6     300    High
# 5226  Grade1       1015  1200.0    50662.8  ...    6     300    High
# 5227  Grade2       1015   400.0    26294.4  ...    6     300    High
# 5228  Grade2       1015   800.0    52588.8  ...    6     300    High
# 5229  Grade2       1015   400.0    26294.4  ...    6     300    High
#
#       Area (km)^2    dfc  population  literacy_rate   pcx  \
# 5225       4394.0  219.2     2756398          0.801  60.1
# 5226       4394.0  219.2     2756398          0.801  60.1
# 5227       4394.0  219.2     2756398          0.801  60.1
# 5228       4394.0  219.2     2756398          0.801  60.1
# 5229       4394.0  219.2     2756398          0.801  60.1
#
#                                              uses  appliation group
# 5225                                 House Wiring           General
# 5226                                 House Wiring           General
# 5227  Air Condition & Washing Machine, Heavy Item          Moderate
# 5228  Air Condition & Washing Machine, Heavy Item          Moderate
# 5229  Air Condition & Washing Machine, Heavy Item          Moderate
#
# [5 rows x 25 columns]

# %%
### laoded successfully

# %% [markdown]
# # Basic Exploratory Data Analysis

# %% [markdown]
# ## Data Summary - Shape, Columns, Types

# %%
df.shape
# Out:
# (5230, 25)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5230 entries, 0 to 5229
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   CID               5230 non-null   int64
#  1   item_type_id      5230 non-null   int64
#  2   item_type         5230 non-null   object
#  3   size              5230 non-null   object
#  4   date              5230 non-null   object
#  5   Category          5230 non-null   object
#  6   grade             5230 non-null   object
#  7   outlet_id         5230 non-null   int64
#  8   qtym              5230 non-null   float64
#  9   Net Price         5230 non-null   float64
#  10  tmtm              5230 non-null   float64
#  11  division          5230 non-null   int64
#  12  item_type_id.1    5230 non-null   int64
#  13  rm                5230 non-null   float64
#  14  wire              5230 non-null   int64
#  15  noc               5230 non-null   int64
#  16  tlcolt            5230 non-null   int64
#  17  ecoInd            5230 non-null   object
#  18  Area (km)^2       5230 non-null   float64
#  19  dfc               5230 non-null   float64
#  20  population        5230 non-null   int64
#  21  literacy_rate     5230 non-null   float64
#  22  pcx               5230 non-null   object
#  23  uses              5230 non-null   object
#  24  appliation group  5230 non-null   object
# dtypes: float64(7), int64(9), object(9)
# memory usage: 1021.6+ KB

# %%
df.head().T
# Out:
#                                           0                          1  \
# CID                                   10001                      10001
# item_type_id                            186                        186
# item_type           BYA LF - Skin Coated FR    BYA LF - Skin Coated FR
# size                        1x 1.0 re (1-w)            1x 1.0 re (1-w)
# date                               01-08-22                   01-08-22
# Category                           Domestic                   Domestic
# grade                                Grade1                     Grade1
# outlet_id                              1001                       1003
# qtym                                  500.0                     2000.0
# Net Price                           7534.96                    32043.0
# tmtm                                  925.0                     3700.0
# division                                 22                         22
# item_type_id.1                          372                        372
# rm                                      2.0                        2.0
# wire                                      2                          2
# noc                                       5                          4
# tlcolt                                  300                        350
# ecoInd                                 High                       High
# Area (km)^2                          3085.0                      928.0
# dfc                                   106.0                      160.0
# population                          6785254                    1823580
# literacy_rate                          0.46                      0.643
# pcx                                    53.3                       59.6
# uses              Fan & Lighting Connection  Fan & Lighting Connection
# appliation group                    General                    General
#
#                                           2                          3  \
# CID                                   10001                      10001
# item_type_id                            186                        186
# item_type           BYA LF - Skin Coated FR    BYA LF - Skin Coated FR
# size                        1x 1.0 re (1-w)            1x 1.0 re (1-w)
# date                               01-08-22                   01-08-22
# Category                           Domestic                   Domestic
# grade                                Grade1                     Grade1
# outlet_id                              1004                       1005
# qtym                                 3000.0                      200.0
# Net Price                           49132.6                     2913.0
# tmtm                                 5550.0                      370.0
# division                                 32                         15
# item_type_id.1                          372                        186
# rm                                      2.0                        1.0
# wire                                      2                          1
# noc                                       7                          3
# tlcolt                                  425                        300
# ecoInd                                 High                       High
# Area (km)^2                          5283.0                     1800.0
# dfc                                   253.0                       26.0
# population                          9352719                    4262296
# literacy_rate                          0.46                      1.047
# pcx                                    58.9                       56.4
# uses              Fan & Lighting Connection  Fan & Lighting Connection
# appliation group                    General                    General
#
#                                           4
# CID                                   10001
# item_type_id                            186
# item_type           BYA LF - Skin Coated FR
# size                        1x 1.0 re (1-w)
# date                               01-08-22
# Category                           Domestic
# grade                                Grade1
# outlet_id                              1010
# qtym                                  600.0
# Net Price                           9476.96
# tmtm                                 1110.0
# division                                 48
# item_type_id.1                          558
# rm                                      3.0
# wire                                      3
# noc                                       7
# tlcolt                                  150
# ecoInd                               Medium
# Area (km)^2                          2492.0
# dfc                                   398.5
# population                          3078190
# literacy_rate                         0.782
# pcx                                    28.3
# uses              Fan & Lighting Connection
# appliation group                    General

# %%
### Structre and type looks fine
### date column needs to be formatted - Cleaning

# %% [markdown]
# ## Check Missing Values

# %%
df.isnull().sum()
# Out:
# CID                 0
# item_type_id        0
# item_type           0
# size                0
# date                0
# Category            0
# grade               0
# outlet_id           0
# qtym                0
# Net Price           0
# tmtm                0
# division            0
# item_type_id.1      0
# rm                  0
# wire                0
# noc                 0
# tlcolt              0
# ecoInd              0
# Area (km)^2         0
# dfc                 0
# population          0
# literacy_rate       0
# pcx                 0
# uses                0
# appliation group    0
# dtype: int64

# %%
### no misssing values

# %% [markdown]
# ## Features

# %%
df.columns
# Out:
# Index(['CID', 'item_type_id', 'item_type', 'size', 'date', 'Category', 'grade',
#        'outlet_id', 'qtym', 'Net Price', 'tmtm', 'division', 'item_type_id.1',
#        'rm', 'wire', 'noc', 'tlcolt', 'ecoInd', 'Area (km)^2', 'dfc',
#        'population', 'literacy_rate', 'pcx', 'uses', 'appliation group'],
#       dtype='object')

# %%
df.drop(columns=['qtym', 'Net Price']).head(3).T
# Out:
#                                           0                          1  \
# CID                                   10001                      10001
# item_type_id                            186                        186
# item_type           BYA LF - Skin Coated FR    BYA LF - Skin Coated FR
# size                        1x 1.0 re (1-w)            1x 1.0 re (1-w)
# date                               01-08-22                   01-08-22
# Category                           Domestic                   Domestic
# grade                                Grade1                     Grade1
# outlet_id                              1001                       1003
# tmtm                                  925.0                     3700.0
# division                                 22                         22
# item_type_id.1                          372                        372
# rm                                      2.0                        2.0
# wire                                      2                          2
# noc                                       5                          4
# tlcolt                                  300                        350
# ecoInd                                 High                       High
# Area (km)^2                          3085.0                      928.0
# dfc                                   106.0                      160.0
# population                          6785254                    1823580
# literacy_rate                          0.46                      0.643
# pcx                                    53.3                       59.6
# uses              Fan & Lighting Connection  Fan & Lighting Connection
# appliation group                    General                    General
#
#                                           2
# CID                                   10001
# item_type_id                            186
# item_type           BYA LF - Skin Coated FR
# size                        1x 1.0 re (1-w)
# date                               01-08-22
# Category                           Domestic
# grade                                Grade1
# outlet_id                              1004
# tmtm                                 5550.0
# division                                 32
# item_type_id.1                          372
# rm                                      2.0
# wire                                      2
# noc                                       7
# tlcolt                                  425
# ecoInd                                 High
# Area (km)^2                          5283.0
# dfc                                   253.0
# population                          9352719
# literacy_rate                          0.46
# pcx                                    58.9
# uses              Fan & Lighting Connection
# appliation group                    General

# %% [markdown]
# ## Targets

# %%
df.loc[:5, ['qtym', 'Net Price']]
# Out:
#      qtym  Net Price
# 0   500.0    7534.96
# 1  2000.0   32043.00
# 2  3000.0   49132.60
# 3   200.0    2913.00
# 4   600.0    9476.96
# 5  1700.0   25420.78

# %% [markdown]
# ## Format Column Names

# %%
### column names need to formatted

# %%
df.columns = [col.replace(' ', '_') for col in df.columns]
df.columns
# Out:
# Index(['CID', 'item_type_id', 'item_type', 'size', 'date', 'Category', 'grade',
#        'outlet_id', 'qtym', 'Net_Price', 'tmtm', 'division', 'item_type_id.1',
#        'rm', 'wire', 'noc', 'tlcolt', 'ecoInd', 'Area_(km)^2', 'dfc',
#        'population', 'literacy_rate', 'pcx', 'uses', 'appliation_group'],
#       dtype='object')

# %% [markdown]
# # Univariate EDA

# %% [markdown]
# ## Continuous

# %% [markdown]
# ### summary stats

# %%
df.describe().T
# Out:
#                  count          mean           std         min          25%  \
# CID             5230.0  1.000795e+04  1.129691e+01   10001.000    10003.000
# item_type_id    5230.0  1.859036e+02  8.117316e-01     177.000      186.000
# outlet_id       5230.0  2.393749e+03  1.056276e+03    1001.000     1011.000
# qtym            5230.0  1.366737e+03  2.539395e+03       1.000      200.000
# Net_Price       5230.0  4.114471e+04  6.328449e+04      34.390     9088.560
# tmtm            5230.0  2.528464e+03  4.697881e+03       1.850      370.000
# division        5230.0  3.076807e+01  2.784032e+01      10.000       14.000
# item_type_id.1  5230.0  4.083455e+02  3.758292e+02     177.000      186.000
# rm              5230.0  5.901482e+00  6.826860e+00       0.750        2.000
# wire            5230.0  1.024742e+01  9.999176e+00       0.000        3.000
# noc             5230.0  4.917208e+00  1.441214e+00       2.000        4.000
# tlcolt          5230.0  2.443669e+02  8.777658e+01     100.000      150.000
# Area_(km)^2     5230.0  1.959257e+03  1.427307e+03       3.080      483.970
# dfc             5230.0  1.820596e+02  1.087199e+02       7.000      106.000
# population      5230.0  2.720186e+06  2.114840e+06  110000.000  1089997.000
# literacy_rate   5230.0  6.452511e-01  2.665359e-01       0.258        0.451
#
#                         50%          75%          max
# CID               10006.000    10011.000    10149.000
# item_type_id        186.000      186.000      186.000
# outlet_id          2561.000     3393.000     4385.000
# qtym                500.000     1400.000    54800.000
# Net_Price         20632.500    45720.000  1251102.400
# tmtm                925.000     2590.000   101380.000
# division             20.000       36.000      336.000
# item_type_id.1      372.000      372.000     5208.000
# rm                    4.000        7.500      119.000
# wire                  7.000       14.000      147.000
# noc                   5.000        6.000        7.000
# tlcolt              250.000      300.000      450.000
# Area_(km)^2        1927.000     2810.000     5283.000
# dfc                 186.300      249.200      468.600
# population      2725224.000  3658027.000  9352719.000
# literacy_rate         0.643        0.782        2.033

# %% [markdown]
# ### distributions

# %%
df.select_dtypes(['float64']).columns
# Out:
# Index(['qtym', 'Net_Price', 'tmtm', 'rm', 'Area_(km)^2', 'dfc',
#        'literacy_rate'],
#       dtype='object')

# %%
# Continuous Feature distribution
cols = list(df.select_dtypes(['float64']).columns)[2:] +['population',]
fig, grid = plt.subplots(3, 2, figsize=(18, 20))
colId = 0
colorPallette = ['set1', 'set2', 'set3']
for row in range(3):
    for col in range(2):
        feature = cols[colId]
        sns.histplot(data=df, ax=grid[row, col], x=feature, label=feature, bins=30)
        grid[row, col].set_title(f'{feature} DIstribution')
        colId += 1
plt.tight_layout()
plt.show()

# %%
# Targets distribution
fig, grid = plt.subplots(1, 2, figsize=(18, 10))
sns.histplot(data=df, ax=grid[0], x='Net_Price', label='Net_Price', bins=30)
grid[0].set_title(f'Net_Price DIstribution')
sns.histplot(data=df, ax=grid[1], x='qtym', label='qtym', bins=30)
grid[1].set_title(f'qtym DIstribution')
plt.tight_layout()
plt.show()

# %%
df.select_dtypes('int64').columns
# Out:
# Index(['CID', 'item_type_id', 'outlet_id', 'division', 'item_type_id.1',
#        'wire', 'noc', 'tlcolt', 'population'],
#       dtype='object')

# %%
# Discrete Feature distribution
cols = ['item_type_id', 'wire', 'noc', 'tlcolt']
fig, grid = plt.subplots(2, 2, figsize=(18, 20))
colId = 0

for row in range(2):
    for col in range(2):
        feature = cols[colId]
        sns.countplot(data=df, ax=grid[row, col], x=feature, label=feature)
        grid[row, col].set_title(f'{feature} Distribution')
        colId += 1        
plt.tight_layout()
plt.show()

# %%
#
cols =['population', 'outlet_id', 'division']
fig, grid = plt.subplots(1, 3, figsize=(16, 16))

for col in range(3):
        feature = cols[col]
        sns.countplot(data=df, ax=grid[col], y=feature, label=feature)
        grid[col].set_title(f'{feature} Distribution')     
plt.tight_layout()
plt.show()

# %%
df.select_dtypes('float64')
# Out:
#         qtym  Net_Price    tmtm    rm  Area_(km)^2    dfc  literacy_rate
# 0      500.0    7534.96   925.0   2.0       3085.0  106.0          0.460
# 1     2000.0   32043.00  3700.0   2.0        928.0  160.0          0.643
# 2     3000.0   49132.60  5550.0   2.0       5283.0  253.0          0.460
# 3      200.0    2913.00   370.0   1.0       1800.0   26.0          1.047
# 4      600.0    9476.96  1110.0   3.0       2492.0  398.5          0.782
# ...      ...        ...     ...   ...          ...    ...            ...
# 5225  1200.0   50662.80  2220.0   5.0       4394.0  219.2          0.801
# 5226  1200.0   50662.80  2220.0   5.0       4394.0  219.2          0.801
# 5227   400.0   26294.40   740.0   8.0       4394.0  219.2          0.801
# 5228   800.0   52588.80  1480.0  16.0       4394.0  219.2          0.801
# 5229   400.0   26294.40   740.0   8.0       4394.0  219.2          0.801
#
# [5230 rows x 7 columns]

# %% [markdown]
# ### Outliers

# %%
fig, grid = plt.subplots(1, 2, figsize=(18, 20))
sns.boxplot(data=df, ax=grid[0], y='Net_Price')
grid[0].set_title(f'Net_Price DIstribution')
sns.boxplot(data=df, ax=grid[1], y='qtym')
grid[1].set_title(f'qtym Distribution')
plt.tight_layout()
plt.show()

# %%
### we have outliers on data, but still analysis is required to know the effect

# %% [markdown]
# ### Univariate - Categorical

# %%
df.select_dtypes('object').columns
# Out:
# Index(['item_type', 'size', 'date', 'Category', 'grade', 'ecoInd', 'pcx',
#        'uses', 'appliation_group'],
#       dtype='object')

# %%
# Categorical Feature distribution
cols =  ['item_type', 'size', 'Category', 'grade', 'ecoInd', 'pcx', 'uses', 'appliation_group']
fig, grid = plt.subplots(4, 2, figsize=(18, 28))
colId = 0

for row in range(4):
    for col in range(2):
        feature = cols[colId]
        sns.countplot(data=df, ax=grid[row, col], y=feature, label=feature)
        grid[row, col].set_title(f'{feature} Distribution')
        colId += 1        
plt.tight_layout()
plt.show()

# %%
### useful insights we got from above
### Most Demand and sales is recodrded, for Domestic use case, on area with high economic index, 
### Garde 1 and 2 sales contributed majorly, 
### number of sales is larger in General category application group
### Most uses in house wiring, Fan and lighting, Air condition, washing machine, heavy item

# %% [markdown]
# ## Multivariate Analysis

# %% [markdown]
# ### Continuous Features

# %%
df.select_dtypes(['float64', 'int64']).columns
# Out:
# Index(['CID', 'item_type_id', 'outlet_id', 'qtym', 'Net_Price', 'tmtm',
#        'division', 'item_type_id.1', 'rm', 'wire', 'noc', 'tlcolt',
#        'Area_(km)^2', 'dfc', 'population', 'literacy_rate'],
#       dtype='object')

# %% [markdown]
# ### Features Target Scatter plot

# %%
features = ['tmtm','division','noc', 'tlcolt','Area_(km)^2', 'dfc', 'population', 'literacy_rate']
sns.pairplot(data=df, x_vars=features, y_vars=['Net_Price', 'qtym'])
plt.show()

# %% [markdown]
# ### correlation analysis

# %%
correlation_matrix = df[features+['Net_Price', 'qtym']].corr()
plt.figure(figsize=(8, 5))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
### Thes is not much linear relationship between features and target, and not evidence of multicolinearity

# %% [markdown]
# ### Categorical - # Multivariate analysis

# %%
df.select_dtypes('object').columns
# Out:
# Index(['item_type', 'size', 'date', 'Category', 'grade', 'ecoInd', 'pcx',
#        'uses', 'appliation_group'],
#       dtype='object')

# %%
cat_features =  ['item_type', 'size', 'Category', 'grade', 'ecoInd', 'pcx', 'uses', 'appliation_group']
fig, grid = plt.subplots(4, 2, figsize=(18, 28))
colId = 0

for row in range(4):
    for col in range(2):
        feature = cols[colId]
        sns.boxplot(data=df, ax=grid[row, col], y=feature, x='Net_Price')
        grid[row, col].set_title(f'Box Plot of Net_Price vs. {feature}')
#         grid[row, col].set_xticks(rotation=45)
        colId += 1        
plt.tight_layout()
plt.show()
