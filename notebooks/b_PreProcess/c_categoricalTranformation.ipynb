# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from feature_engine.encoding import OrdinalEncoder

# %%
data = pd.read_parquet('d:/demand-forecast-SQGroup/data/sales_bya_v1.parquet')

# %%
data.head().T
# Out:
#                                             0                          1  \
# cid                                     10001                      10001
# item_type_id                              186                        186
# category                             Domestic                   Domestic
# date                      2020-01-01 00:00:00        2020-01-01 00:00:00
# outlet_id                                1003                       1003
# wire                                        1                          1
# rm                                        1.0                        1.0
# fy                                         17                         17
# base_size                     1x 1.0 re (1-w)            1x 1.0 re (1-w)
# client_id                    3DHEHE9HHE9H5MAK           3DHEHE9HHE9H9H1L
# qtym                               120.400002                  61.599998
# net_price                         2104.351318                 957.017578
# grade                                  Grade1                     Grade1
# uses                Fan & Lighting Connection  Fan & Lighting Connection
# application_group                     General                    General
# noc                                         4                          4
# dfc                                     160.0                      160.0
# area_km2                                928.0                      928.0
# population                            1823580                    1823580
# literacy_rate_perc                  59.599998                  59.599998
# pcx                                     0.643                      0.643
# excnts                                     11                         11
# exach                                86.24247                   86.24247
# trc                                       379                        379
# tlcolt                                    350                        350
# tmtm                               981.342773                 502.082336
# ecoind                                   High                       High
# division                           Chittagong                 Chittagong
# sf                                          5                          5
# sop                                         4                          4
# pminx                                       5                          5
# tms_cr                               3.761494                   3.761494
# mas                                  0.461494                   0.461494
# kpi                                       0.6                        0.6
# mkt                                     Urban                      Rural
#
#                                             2                          3  \
# cid                                     10001                      10001
# item_type_id                              186                        186
# category                             Domestic                   Domestic
# date                      2020-01-01 00:00:00        2020-01-01 00:00:00
# outlet_id                                1003                       1003
# wire                                        1                          1
# rm                                        1.0                        1.0
# fy                                         17                         17
# base_size                     1x 1.0 re (1-w)            1x 1.0 re (1-w)
# client_id                    3DHEHE9HHEHE3DHE           3DHEHE9HHEHE4N7O
# qtym                                    574.0                 310.799988
# net_price                         10032.37207                4526.801758
# grade                                  Grade1                     Grade1
# uses                Fan & Lighting Connection  Fan & Lighting Connection
# application_group                     General                    General
# noc                                         4                          4
# dfc                                     160.0                      160.0
# area_km2                                928.0                      928.0
# population                            1823580                    1823580
# literacy_rate_perc                  59.599998                  59.599998
# pcx                                     0.643                      0.643
# excnts                                     11                         11
# exach                                86.24247                   86.24247
# trc                                       379                        379
# tlcolt                                    350                        350
# tmtm                              4678.494629                2533.233643
# ecoind                                   High                       High
# division                           Chittagong                 Chittagong
# sf                                          5                          5
# sop                                         4                          4
# pminx                                       5                          5
# tms_cr                               3.761494                   3.761494
# mas                                  0.461494                   0.461494
# kpi                                       0.6                        0.6
# mkt                                     Urban                      Urban
#
#                                             4
# cid                                     10001
# item_type_id                              186
# category                             Domestic
# date                      2020-01-01 00:00:00
# outlet_id                                1003
# wire                                        1
# rm                                        1.0
# fy                                         17
# base_size                     1x 1.0 re (1-w)
# client_id                    3DHEHE9HHEHEHEAK
# qtym                               123.199997
# net_price                         2153.289551
# grade                                  Grade1
# uses                Fan & Lighting Connection
# application_group                     General
# noc                                         4
# dfc                                     160.0
# area_km2                                928.0
# population                            1823580
# literacy_rate_perc                  59.599998
# pcx                                     0.643
# excnts                                     11
# exach                                86.24247
# trc                                       379
# tlcolt                                    350
# tmtm                              1004.164673
# ecoind                                   High
# division                           Chittagong
# sf                                          5
# sop                                         4
# pminx                                       5
# tms_cr                               3.761494
# mas                                  0.461494
# kpi                                       0.6
# mkt                                     Urban

# %%
data.tail().T
# Out:
#                                                          353591  \
# cid                                                       10149
# item_type_id                                                180
# category                                               Domestic
# date                                        2020-07-09 00:00:00
# outlet_id                                                  1015
# wire                                                          0
# rm                                                          4.0
# fy                                                           18
# base_size                                            1 x 4.0 rm
# client_id                                      3DHE3D5MHE3D1L2P
# qtym                                                  318.48999
# net_price                                          20936.257812
# grade                                                    Grade2
# uses                Air Condition & Washing Machine, Heavy Item
# application_group                                      Moderate
# noc                                                           6
# dfc                                                  219.199997
# area_km2                                                 4394.0
# population                                              2756398
# literacy_rate_perc                                    60.099998
# pcx                                                       0.801
# excnts                                                       17
# exach                                                 82.657478
# trc                                                         297
# tlcolt                                                      300
# tmtm                                                2427.509521
# ecoind                                                     High
# division                                                 Khulna
# sf                                                            8
# sop                                                           7
# pminx                                                         6
# tms_cr                                                 5.294661
# mas                                                    0.694661
# kpi                                                         0.1
# mkt                                                      Others
#
#                                                          353592  \
# cid                                                       10149
# item_type_id                                                180
# category                                               Domestic
# date                                        2022-08-11 00:00:00
# outlet_id                                                  1015
# wire                                                          0
# rm                                                          4.0
# fy                                                           20
# base_size                                            1 x 4.0 rm
# client_id                                      3DHE3D5MHE3D1L2P
# qtym                                                      400.0
# net_price                                          26294.400391
# grade                                                    Grade2
# uses                Air Condition & Washing Machine, Heavy Item
# application_group                                      Moderate
# noc                                                           6
# dfc                                                  219.199997
# area_km2                                                 4394.0
# population                                              2756398
# literacy_rate_perc                                    60.099998
# pcx                                                       0.801
# excnts                                                       17
# exach                                                 82.657478
# trc                                                         297
# tlcolt                                                      300
# tmtm                                                3048.773438
# ecoind                                                     High
# division                                                 Khulna
# sf                                                            8
# sop                                                           7
# pminx                                                         6
# tms_cr                                                 5.294661
# mas                                                    0.694661
# kpi                                                         0.1
# mkt                                                      Others
#
#                                                          353593  \
# cid                                                       10149
# item_type_id                                                180
# category                                               Domestic
# date                                        2019-09-10 00:00:00
# outlet_id                                                  1015
# wire                                                          0
# rm                                                          4.0
# fy                                                           17
# base_size                                            1 x 4.0 rm
# client_id                                      3DHE3D5MHE3D1L2P
# qtym                                                      198.0
# net_price                                          13015.727539
# grade                                                    Grade2
# uses                Air Condition & Washing Machine, Heavy Item
# application_group                                      Moderate
# noc                                                           6
# dfc                                                  219.199997
# area_km2                                                 4394.0
# population                                              2756398
# literacy_rate_perc                                    60.099998
# pcx                                                       0.801
# excnts                                                       17
# exach                                                 82.657478
# trc                                                         297
# tlcolt                                                      300
# tmtm                                                1509.142822
# ecoind                                                     High
# division                                                 Khulna
# sf                                                            8
# sop                                                           7
# pminx                                                         6
# tms_cr                                                 5.294661
# mas                                                    0.694661
# kpi                                                         0.1
# mkt                                                      Others
#
#                                                          353594  \
# cid                                                       10149
# item_type_id                                                180
# category                                               Domestic
# date                                        2021-09-11 00:00:00
# outlet_id                                                  1015
# wire                                                          0
# rm                                                          4.0
# fy                                                           19
# base_size                                            1 x 4.0 rm
# client_id                                      3DHE3D5MHE3D1L2P
# qtym                                                      160.0
# net_price                                          10517.759766
# grade                                                    Grade2
# uses                Air Condition & Washing Machine, Heavy Item
# application_group                                      Moderate
# noc                                                           6
# dfc                                                  219.199997
# area_km2                                                 4394.0
# population                                              2756398
# literacy_rate_perc                                    60.099998
# pcx                                                       0.801
# excnts                                                       17
# exach                                                 82.657478
# trc                                                         297
# tlcolt                                                      300
# tmtm                                                1219.509399
# ecoind                                                     High
# division                                                 Khulna
# sf                                                            8
# sop                                                           7
# pminx                                                         6
# tms_cr                                                 5.294661
# mas                                                    0.694661
# kpi                                                         0.1
# mkt                                                      Others
#
#                                                          353595
# cid                                                       10149
# item_type_id                                                180
# category                                               Domestic
# date                                        2022-09-11 00:00:00
# outlet_id                                                  1015
# wire                                                          0
# rm                                                          4.0
# fy                                                           20
# base_size                                            1 x 4.0 rm
# client_id                                      3DHE3D5MHE3D1L2P
# qtym                                                      324.0
# net_price                                          21298.464844
# grade                                                    Grade2
# uses                Air Condition & Washing Machine, Heavy Item
# application_group                                      Moderate
# noc                                                           6
# dfc                                                  219.199997
# area_km2                                                 4394.0
# population                                              2756398
# literacy_rate_perc                                    60.099998
# pcx                                                       0.801
# excnts                                                       17
# exach                                                 82.657478
# trc                                                         297
# tlcolt                                                      300
# tmtm                                                2469.506348
# ecoind                                                     High
# division                                                 Khulna
# sf                                                            8
# sop                                                           7
# pminx                                                         6
# tms_cr                                                 5.294661
# mas                                                    0.694661
# kpi                                                         0.1
# mkt                                                      Others

# %%
### structural info
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 353596 entries, 0 to 353595
# Data columns (total 35 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   cid                 353596 non-null  int32
#  1   item_type_id        353596 non-null  int32
#  2   category            353596 non-null  object
#  3   date                353596 non-null  datetime64[ns]
#  4   outlet_id           353596 non-null  int32
#  5   wire                353596 non-null  int32
#  6   rm                  353596 non-null  float32
#  7   fy                  353596 non-null  int32
#  8   base_size           353596 non-null  object
#  9   client_id           353596 non-null  object
#  10  qtym                353596 non-null  float32
#  11  net_price           353596 non-null  float32
#  12  grade               353596 non-null  object
#  13  uses                353596 non-null  object
#  14  application_group   353596 non-null  object
#  15  noc                 353596 non-null  int32
#  16  dfc                 353596 non-null  float32
#  17  area_km2            353596 non-null  float32
#  18  population          353596 non-null  int32
#  19  literacy_rate_perc  353596 non-null  float32
#  20  pcx                 353596 non-null  float32
#  21  excnts              353596 non-null  int32
#  22  exach               353596 non-null  float32
#  23  trc                 353596 non-null  int32
#  24  tlcolt              353596 non-null  int32
#  25  tmtm                353596 non-null  float32
#  26  ecoind              353596 non-null  object
#  27  division            353596 non-null  object
#  28  sf                  353596 non-null  int32
#  29  sop                 353596 non-null  int32
#  30  pminx               353596 non-null  int32
#  31  tms_cr              353596 non-null  float32
#  32  mas                 353596 non-null  float32
#  33  kpi                 353596 non-null  float32
#  34  mkt                 353596 non-null  object
# dtypes: datetime64[ns](1), float32(12), int32(13), object(9)
# memory usage: 60.7+ MB

# %%
### checking missing values
data.isnull().sum()
# Out:
# cid                   0
# item_type_id          0
# category              0
# date                  0
# outlet_id             0
# wire                  0
# rm                    0
# fy                    0
# base_size             0
# client_id             0
# qtym                  0
# net_price             0
# grade                 0
# uses                  0
# application_group     0
# noc                   0
# dfc                   0
# area_km2              0
# population            0
# literacy_rate_perc    0
# pcx                   0
# excnts                0
# exach                 0
# trc                   0
# tlcolt                0
# tmtm                  0
# ecoind                0
# division              0
# sf                    0
# sop                   0
# pminx                 0
# tms_cr                0
# mas                   0
# kpi                   0
# mkt                   0
# dtype: int64

# %%
df = data.copy()

# %% [markdown]
# <center><h1>Categorical Encoding</h1></center>

# %%
def encode(df: pd.DataFrame) -> None:
    df['category'] = df.category.apply(lambda cat: {'Domestic': 1, 'Power':0}[cat])
    
    df['grade'] = df.grade.apply(
        lambda cat: {'Grade1': 1, 'Grade2': 2, 'Grade3': 3, 'Grade4': 4}[cat]
    )
    
    df['uses'] = df.uses.apply(
            lambda cat: {
                'House Wiring': 1,
                 'Fan & Lighting Connection': 2,
                 'Air Condition & Washing Machine, Heavy Item': 3,
                 'Lift & Heavy Item': 4,
                 'Earthing':5,
                 'Industry, Machineries': 6
            }[cat]
    )
    
    df['application_group'] = df.application_group.apply(
        lambda cat: {
            'General': 1, 'Moderate': 2, 'Rich': 3, 'Industry': 4
        }[cat]
    )
    
    df['ecoind'] = df.ecoind.apply(
        lambda cat: {'Medium': 2, 'High': 4, 'Low': 2, 'Poor': 1}[cat]
    )
    
    df['division'] = df.division.apply(
        lambda cat: {
            'Dhaka': 1,
            'Chittagong': 2,
            'Khulna': 3,
            'Rajshahi': 4,
            'Mymensingh': 5,
            'Sylhet': 6,
            'Rangpur': 7,
            'Barishal': 8}[cat]
    )
    
    df['mkt'] = df.mkt.str.strip(' ').apply(
        lambda cat: {
            'Urban': 4,
            'Semi Urban': 3, 
            'Rural': 2, 
            'Others': 1, 
        }[cat]
    )
    
    ### base_size ordinal encoding
    encoder = OrdinalEncoder(
        encoding_method='ordered', 
        variables=None, missing_values='raise', 
        ignore_format=False, unseen='ignore'
    )
    encoder.fit(df[['base_size']], y=df.net_price)
    df['base_size'] = encoder.transform(df[['base_size']]).base_size
    
    ### optimize for memory
    for col in df.select_dtypes('int64').columns:
        df[col] = df[col].astype('int32')

# %%
### encoding
cat = df.select_dtypes('object')

# %%
cat.category.value_counts()
# Out:
# category
# Domestic    351161
# Power         2435
# Name: count, dtype: int64

# %%
cat.category
# Out:
# 0         Domestic
# 1         Domestic
# 2         Domestic
# 3         Domestic
# 4         Domestic
#             ...
# 353591    Domestic
# 353592    Domestic
# 353593    Domestic
# 353594    Domestic
# 353595    Domestic
# Name: category, Length: 353596, dtype: object

# %%
cat['category'] = cat.category.apply(lambda cat: {'Domestic': 1, 'Power':0}[cat])

# %%
cat.category.value_counts()
# Out:
# category
# 1    351161
# 0      2435
# Name: count, dtype: int64

# %%
cat.T
# Out:
#                                       0                          1       \
# category                                   1                          1
# base_size                    1x 1.0 re (1-w)            1x 1.0 re (1-w)
# client_id                   3DHEHE9HHE9H5MAK           3DHEHE9HHE9H9H1L
# grade                                 Grade1                     Grade1
# uses               Fan & Lighting Connection  Fan & Lighting Connection
# application_group                    General                    General
# ecoind                                  High                       High
# division                          Chittagong                 Chittagong
# mkt                                    Urban                      Rural
#
#                                       2                          3       \
# category                                   1                          1
# base_size                    1x 1.0 re (1-w)            1x 1.0 re (1-w)
# client_id                   3DHEHE9HHEHE3DHE           3DHEHE9HHEHE4N7O
# grade                                 Grade1                     Grade1
# uses               Fan & Lighting Connection  Fan & Lighting Connection
# application_group                    General                    General
# ecoind                                  High                       High
# division                          Chittagong                 Chittagong
# mkt                                    Urban                      Urban
#
#                                       4                          5       \
# category                                   1                          1
# base_size                    1x 1.0 re (1-w)            1x 1.0 re (1-w)
# client_id                   3DHEHE9HHEHEHEAK           3DHEHE1LHE9H5M1L
# grade                                 Grade1                     Grade1
# uses               Fan & Lighting Connection  Fan & Lighting Connection
# application_group                    General                    General
# ecoind                                  High                       High
# division                          Chittagong                 Chittagong
# mkt                                    Urban                     Others
#
#                                       6                          7       \
# category                                   1                          1
# base_size                    1x 1.0 re (1-w)            1x 1.0 re (1-w)
# client_id                   3DHEHE5MHE3D9H2P           3DHEHE5MHESOHE4N
# grade                                 Grade1                     Grade1
# uses               Fan & Lighting Connection  Fan & Lighting Connection
# application_group                    General                    General
# ecoind                                  High                       High
# division                               Dhaka                      Dhaka
# mkt                                    Urban                      Urban
#
#                                       8                          9       ...  \
# category                                   1                          1  ...
# base_size                    1x 1.0 re (1-w)            1x 1.0 re (1-w)  ...
# client_id                   3DHEHE4NHE3D2P1L           3DHEHE7OHE9HSO3D  ...
# grade                                 Grade1                     Grade1  ...
# uses               Fan & Lighting Connection  Fan & Lighting Connection  ...
# application_group                    General                    General  ...
# ecoind                                Medium                       High  ...
# division                              Khulna                     Sylhet  ...
# mkt                                    Rural                 Semi Urban  ...
#
#                                                         353586  \
# category                                                     1
# base_size                                           1 x 4.0 rm
# client_id                                     3DHE3D5MHE3D1L2P
# grade                                                   Grade2
# uses               Air Condition & Washing Machine, Heavy Item
# application_group                                     Moderate
# ecoind                                                    High
# division                                                Khulna
# mkt                                                     Others
#
#                                                         353587  \
# category                                                     1
# base_size                                           1 x 4.0 rm
# client_id                                     3DHE3D5MHE3D1L2P
# grade                                                   Grade2
# uses               Air Condition & Washing Machine, Heavy Item
# application_group                                     Moderate
# ecoind                                                    High
# division                                                Khulna
# mkt                                                     Others
#
#                                                         353588  \
# category                                                     1
# base_size                                           1 x 4.0 rm
# client_id                                     3DHE3D5MHE3D1L2P
# grade                                                   Grade2
# uses               Air Condition & Washing Machine, Heavy Item
# application_group                                     Moderate
# ecoind                                                    High
# division                                                Khulna
# mkt                                                     Others
#
#                                                         353589  \
# category                                                     1
# base_size                                           1 x 4.0 rm
# client_id                                     3DHE3D5MHE3D1L2P
# grade                                                   Grade2
# uses               Air Condition & Washing Machine, Heavy Item
# application_group                                     Moderate
# ecoind                                                    High
# division                                                Khulna
# mkt                                                     Others
#
#                                                         353590  \
# category                                                     1
# base_size                                           1 x 4.0 rm
# client_id                                     3DHE3D5MHE3D1L2P
# grade                                                   Grade2
# uses               Air Condition & Washing Machine, Heavy Item
# application_group                                     Moderate
# ecoind                                                    High
# division                                                Khulna
# mkt                                                     Others
#
#                                                         353591  \
# category                                                     1
# base_size                                           1 x 4.0 rm
# client_id                                     3DHE3D5MHE3D1L2P
# grade                                                   Grade2
# uses               Air Condition & Washing Machine, Heavy Item
# application_group                                     Moderate
# ecoind                                                    High
# division                                                Khulna
# mkt                                                     Others
#
#                                                         353592  \
# category                                                     1
# base_size                                           1 x 4.0 rm
# client_id                                     3DHE3D5MHE3D1L2P
# grade                                                   Grade2
# uses               Air Condition & Washing Machine, Heavy Item
# application_group                                     Moderate
# ecoind                                                    High
# division                                                Khulna
# mkt                                                     Others
#
#                                                         353593  \
# category                                                     1
# base_size                                           1 x 4.0 rm
# client_id                                     3DHE3D5MHE3D1L2P
# grade                                                   Grade2
# uses               Air Condition & Washing Machine, Heavy Item
# application_group                                     Moderate
# ecoind                                                    High
# division                                                Khulna
# mkt                                                     Others
#
#                                                         353594  \
# category                                                     1
# base_size                                           1 x 4.0 rm
# client_id                                     3DHE3D5MHE3D1L2P
# grade                                                   Grade2
# uses               Air Condition & Washing Machine, Heavy Item
# application_group                                     Moderate
# ecoind                                                    High
# division                                                Khulna
# mkt                                                     Others
#
#                                                         353595
# category                                                     1
# base_size                                           1 x 4.0 rm
# client_id                                     3DHE3D5MHE3D1L2P
# grade                                                   Grade2
# uses               Air Condition & Washing Machine, Heavy Item
# application_group                                     Moderate
# ecoind                                                    High
# division                                                Khulna
# mkt                                                     Others
#
# [9 rows x 353596 columns]

# %%
cat.grade.value_counts().to_dict()
# Out:
# {'Grade1': 290132, 'Grade2': 54256, 'Grade3': 8036, 'Grade4': 1172}

# %%
cat.uses.value_counts().to_dict()
# Out:
# {'House Wiring': 158646,
#  'Fan & Lighting Connection': 125925,
#  'Air Condition & Washing Machine, Heavy Item': 54256,
#  'Lift & Heavy Item': 6773,
#  'Earthing': 5561,
#  'Industry, Machineries': 2435}

# %%
cat.application_group.value_counts().to_dict()
# Out:
# {'General': 290132, 'Moderate': 54256, 'Rich': 8036, 'Industry': 1172}

# %%
cat.ecoind.value_counts().to_dict()
# Out:
# {'Medium': 161523, 'High': 144250, 'Low': 43998, 'Poor': 3825}

# %%
cat.division.value_counts().to_dict()
# Out:
# {'Dhaka': 83777,
#  'Chittagong': 82999,
#  'Khulna': 47060,
#  'Rajshahi': 39035,
#  'Mymensingh': 35859,
#  'Sylhet': 33205,
#  'Rangpur': 24860,
#  'Barishal': 6801}

# %%
cat.mkt.str.strip(' ').value_counts().to_dict()
# Out:
# {'Urban': 218061, 'Semi Urban': 55521, 'Rural': 40328, 'Others': 39686}

# %%
cat.base_size.value_counts()
# Out:
# base_size
# 1x 2.0 rm (3-w)      59601
# 1x 1.3 rm (3-w)      58566
# 1x 1.0 rm (3-w)      45759
# 1x 2.5 rm (7-w)      27389
# 1x 3 rm (7-w)        27293
# 1x 1.5 rm (7-w)      26464
# 1x 1.0 re (1-w)      21538
# 1x 4 rm (7-w)        19709
# 1x 4.5 rm (7-w)      16962
# 1x 1.5 re (1-w)      13472
# 1x 7 rm (7-w)        10653
# 1x 6 rm (7-w)         6833
# 1x 10 rm (7-w)        6773
# 1x 0.75 rm (3-w)      5444
# 1x 2.5 re (1-W)       2542
# 1x 1.5 rm (3-w)       1705
# 1x 14.5 rm (7-w)      1216
# 1 x 16 rm (19-w)       708
# 1 x 16 rm (7-w)        461
# 1 x 0.75 re (1-w)      117
# 1 x 2.5 rm (7-w)        48
# 1 x 14.5 rm (7-w)       47
# 1x 2.5 re (1-w)         46
# 1 x 2.0 Rm (3-w)        44
# 1 x 1.0 re (1-w)        44
# 1 x 6 rm (7-w)          35
# 1x 4.0 re (1-w)         32
# 1 x 4.0 rm              32
# 1 x 1.5 rm (7-w)        26
# 1 x 1.0 rm              18
# 1 x 2.5 re (1-w)        16
# 1x 16 rm (19-w)          3
# Name: count, dtype: int64

# %%
df.base_size
# Out:
# 0         1x 1.0 re (1-w)
# 1         1x 1.0 re (1-w)
# 2         1x 1.0 re (1-w)
# 3         1x 1.0 re (1-w)
# 4         1x 1.0 re (1-w)
#                ...
# 353591         1 x 4.0 rm
# 353592         1 x 4.0 rm
# 353593         1 x 4.0 rm
# 353594         1 x 4.0 rm
# 353595         1 x 4.0 rm
# Name: base_size, Length: 353596, dtype: object

# %%
encoder = OrdinalEncoder(
    encoding_method='ordered', 
    variables=None, missing_values='raise', 
    ignore_format=False, unseen='ignore'
)

# %%
encoder.fit(df[['base_size']], y=df.net_price)
# Out:
# OrdinalEncoder()

# %%
encoder.transform(df[['base_size']])
# Out:
#         base_size
# 0               6
# 1               6
# 2               6
# 3               6
# 4               6
# ...           ...
# 353591         22
# 353592         22
# 353593         22
# 353594         22
# 353595         22
#
# [353596 rows x 1 columns]

# %%
encoder.encoder_dict_
# Out:
# {'base_size': {'1 x 1.0 re (1-w)': 0,
#   '1x 2.5 re (1-w)': 1,
#   '1 x 2.5 re (1-w)': 2,
#   '1 x 2.0 Rm (3-w)': 3,
#   '1 x 0.75 re (1-w)': 4,
#   '1x 4.0 re (1-w)': 5,
#   '1x 1.0 re (1-w)': 6,
#   '1x 1.5 rm (3-w)': 7,
#   '1x 1.5 re (1-w)': 8,
#   '1x 0.75 rm (3-w)': 9,
#   '1 x 6 rm (7-w)': 10,
#   '1x 2.5 re (1-W)': 11,
#   '1x 16 rm (19-w)': 12,
#   '1 x 1.0 rm': 13,
#   '1x 1.0 rm (3-w)': 14,
#   '1x 3 rm (7-w)': 15,
#   '1x 4 rm (7-w)': 16,
#   '1 x 14.5 rm (7-w)': 17,
#   '1x 1.5 rm (7-w)': 18,
#   '1x 4.5 rm (7-w)': 19,
#   '1x 6 rm (7-w)': 20,
#   '1 x 1.5 rm (7-w)': 21,
#   '1 x 4.0 rm': 22,
#   '1x 1.3 rm (3-w)': 23,
#   '1x 2.0 rm (3-w)': 24,
#   '1x 2.5 rm (7-w)': 25,
#   '1x 7 rm (7-w)': 26,
#   '1x 14.5 rm (7-w)': 27,
#   '1 x 16 rm (19-w)': 28,
#   '1x 10 rm (7-w)': 29,
#   '1 x 2.5 rm (7-w)': 30,
#   '1 x 16 rm (7-w)': 31}}

# %%
encode(data)

# %%
data.head().T
# Out:
#                                       0                    1  \
# cid                               10001                10001
# item_type_id                        186                  186
# category                              1                    1
# date                2020-01-01 00:00:00  2020-01-01 00:00:00
# outlet_id                          1003                 1003
# wire                                  1                    1
# rm                                  1.0                  1.0
# fy                                   17                   17
# base_size                             6                    6
# client_id              3DHEHE9HHE9H5MAK     3DHEHE9HHE9H9H1L
# qtym                         120.400002            61.599998
# net_price                   2104.351318           957.017578
# grade                                 1                    1
# uses                                  2                    2
# application_group                     1                    1
# noc                                   4                    4
# dfc                               160.0                160.0
# area_km2                          928.0                928.0
# population                      1823580              1823580
# literacy_rate_perc            59.599998            59.599998
# pcx                               0.643                0.643
# excnts                               11                   11
# exach                          86.24247             86.24247
# trc                                 379                  379
# tlcolt                              350                  350
# tmtm                         981.342773           502.082336
# ecoind                                4                    4
# division                              2                    2
# sf                                    5                    5
# sop                                   4                    4
# pminx                                 5                    5
# tms_cr                         3.761494             3.761494
# mas                            0.461494             0.461494
# kpi                                 0.6                  0.6
# mkt                                   4                    2
#
#                                       2                    3  \
# cid                               10001                10001
# item_type_id                        186                  186
# category                              1                    1
# date                2020-01-01 00:00:00  2020-01-01 00:00:00
# outlet_id                          1003                 1003
# wire                                  1                    1
# rm                                  1.0                  1.0
# fy                                   17                   17
# base_size                             6                    6
# client_id              3DHEHE9HHEHE3DHE     3DHEHE9HHEHE4N7O
# qtym                              574.0           310.799988
# net_price                   10032.37207          4526.801758
# grade                                 1                    1
# uses                                  2                    2
# application_group                     1                    1
# noc                                   4                    4
# dfc                               160.0                160.0
# area_km2                          928.0                928.0
# population                      1823580              1823580
# literacy_rate_perc            59.599998            59.599998
# pcx                               0.643                0.643
# excnts                               11                   11
# exach                          86.24247             86.24247
# trc                                 379                  379
# tlcolt                              350                  350
# tmtm                        4678.494629          2533.233643
# ecoind                                4                    4
# division                              2                    2
# sf                                    5                    5
# sop                                   4                    4
# pminx                                 5                    5
# tms_cr                         3.761494             3.761494
# mas                            0.461494             0.461494
# kpi                                 0.6                  0.6
# mkt                                   4                    4
#
#                                       4
# cid                               10001
# item_type_id                        186
# category                              1
# date                2020-01-01 00:00:00
# outlet_id                          1003
# wire                                  1
# rm                                  1.0
# fy                                   17
# base_size                             6
# client_id              3DHEHE9HHEHEHEAK
# qtym                         123.199997
# net_price                   2153.289551
# grade                                 1
# uses                                  2
# application_group                     1
# noc                                   4
# dfc                               160.0
# area_km2                          928.0
# population                      1823580
# literacy_rate_perc            59.599998
# pcx                               0.643
# excnts                               11
# exach                          86.24247
# trc                                 379
# tlcolt                              350
# tmtm                        1004.164673
# ecoind                                4
# division                              2
# sf                                    5
# sop                                   4
# pminx                                 5
# tms_cr                         3.761494
# mas                            0.461494
# kpi                                 0.6
# mkt                                   4

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 353596 entries, 0 to 353595
# Data columns (total 35 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   cid                 353596 non-null  int32
#  1   item_type_id        353596 non-null  int32
#  2   category            353596 non-null  int32
#  3   date                353596 non-null  datetime64[ns]
#  4   outlet_id           353596 non-null  int32
#  5   wire                353596 non-null  int32
#  6   rm                  353596 non-null  float32
#  7   fy                  353596 non-null  int32
#  8   base_size           353596 non-null  int32
#  9   client_id           353596 non-null  object
#  10  qtym                353596 non-null  float32
#  11  net_price           353596 non-null  float32
#  12  grade               353596 non-null  int32
#  13  uses                353596 non-null  int32
#  14  application_group   353596 non-null  int32
#  15  noc                 353596 non-null  int32
#  16  dfc                 353596 non-null  float32
#  17  area_km2            353596 non-null  float32
#  18  population          353596 non-null  int32
#  19  literacy_rate_perc  353596 non-null  float32
#  20  pcx                 353596 non-null  float32
#  21  excnts              353596 non-null  int32
#  22  exach               353596 non-null  float32
#  23  trc                 353596 non-null  int32
#  24  tlcolt              353596 non-null  int32
#  25  tmtm                353596 non-null  float32
#  26  ecoind              353596 non-null  int32
#  27  division            353596 non-null  int32
#  28  sf                  353596 non-null  int32
#  29  sop                 353596 non-null  int32
#  30  pminx               353596 non-null  int32
#  31  tms_cr              353596 non-null  float32
#  32  mas                 353596 non-null  float32
#  33  kpi                 353596 non-null  float32
#  34  mkt                 353596 non-null  int32
# dtypes: datetime64[ns](1), float32(12), int32(21), object(1)
# memory usage: 49.9+ MB

# %%
data.to_parquet('d:/demand-forecast-SQGroup/data/sales_bya_v2.parquet', index=False)
